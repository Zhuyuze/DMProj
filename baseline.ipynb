# %%
import pandas as pd
import numpy as np
import lightgbm as lgb

# %%
pd.set_option('display.max_columns',None)

# %%
#读取数据
age_train = pd.read_csv("age_train.csv", names=['uid','age_group'])
age_test = pd.read_csv("age_test.csv", names=['uid'])
user_basic_info = pd.read_csv("user_basic_info.csv", names=['uid','gender','city','prodName','ramCapacity','ramLeftRation','romCapacity','romLeftRation','color','fontSize','ct','carrier','os'])
user_behavior_info = pd.read_csv("user_behavior_info.csv", names=['uid','bootTimes','AFuncTimes','BFuncTimes','CFuncTimes','DFuncTimes','EFuncTimes','FFuncTimes','FFuncSum'])
user_app_actived = pd.read_csv("user_app_actived.csv", names=['uid','appId'])
#user_app_usage = pd.read_csv("user_app_usage.csv")
app_info = pd.read_csv("app_info.csv", names=['appId', 'category'])

# %%
#处理数据量较大的user_app_usage.csv，结合app_info.csv简单统计得到appuseProcessed.csv作为特征
def f(x):
    s = x.value_counts()
    return np.nan if len(s) == 0 else s.index[0]
def processUserAppUsage():
    resTable = pd.DataFrame()
    reader = pd.read_csv("user_app_usage.csv", names=['uid','appId','duration','times','use_date'], iterator=True)
    last_df = pd.DataFrame()
    
    app_info = pd.read_csv("app_info.csv", names=['appId','category'])
    cats = list(set(app_info['category']))
    category2id = dict(zip(sorted(cats), range(0,len(cats))))
    id2category = dict(zip(range(0,len(cats)), sorted(cats)))
    app_info['category'] = app_info['category'].apply(lambda x: category2id[x])
    i = 1
    
    while True:
        try:
            print("index: {}".format(i))
            i+=1
            df = reader.get_chunk(1000000)
            df = pd.concat([last_df, df])
            idx = df.shape[0]-1
            last_user = df.iat[idx,0]
            while(df.iat[idx,0]==last_user):
                idx-=1
            last_df = df[idx+1:]
            df = df[:idx+1]

            now_df = pd.DataFrame()
            now_df['uid'] = df['uid'].unique()
            now_df = now_df.merge(df.groupby('uid')['appId'].count().to_frame(), how='left', on='uid')
            now_df = now_df.merge(df.groupby('uid')['appId','use_date'].agg(['nunique']), how='left', on='uid')
            now_df = now_df.merge(df.groupby('uid')['duration','times'].agg(['mean','max','std']), how='left', on='uid')    

            now_df.columns = ['uid','usage_cnt','usage_appid_cnt','usage_date_cnt','duration_mean','duration_max','duration_std','times_mean','times_max','times_std']


            df = df.merge(app_info, how='left', on='appId')
            now_df = now_df.merge(df.groupby('uid')['category'].nunique().to_frame(), how='left', on='uid')
            #print(df.groupby(['uid'])['category'].value_counts().index[0])
            now_df['usage_most_used_category'] = df.groupby(['uid'])['category'].transform(f)
            resTable = pd.concat([resTable, now_df])
        except StopIteration:
            break
    
    resTable.to_csv("appuseProcessed.csv",index=0)
    
    print("Iterator is stopped")

# %%
processUserAppUsage()
# Out:
# index: 1
# /home/mmm/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/reshape/merge.py:544: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# (1000364, 18.0)
# index: 2
# (1845664, 7.0)
# index: 3
# (1000107, 17.0)
# index: 4
# (1060334, 17.0)
# index: 5
# (1895014, 17.0)
# index: 6
# (1000237, 17.0)
# index: 7
# (1114846, 17.0)
# index: 8
# (1974375, 17.0)
# index: 9
# (1000143, 17.0)
# index: 10
# (1139447, 17.0)
# index: 11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-86cc0ab52f52> in <module>
# ----> 1 processUserAppUsage()
#
# <ipython-input-2-f2c61b1d4488> in processUserAppUsage()
#      31             now_df['uid'] = df['uid'].unique()
#      32             now_df = now_df.merge(df.groupby('uid')['appId'].count().to_frame(), how='left', on='uid')
# ---> 33             now_df = now_df.merge(df.groupby('uid')['appId','use_date'].agg(['nunique']), how='left', on='uid')
#      34             now_df = now_df.merge(df.groupby('uid')['duration','times'].agg(['mean','max','std']), how='left', on='uid')
#      35
#
# ~/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, arg, *args, **kwargs)
#    4654         axis=''))
#    4655     def aggregate(self, arg, *args, **kwargs):
# -> 4656         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4657
#    4658     agg = aggregate
#
# ~/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, arg, *args, **kwargs)
#    4085
#    4086         _level = kwargs.pop('_level', None)
# -> 4087         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    4088         if how is None:
#    4089             return result
#
# ~/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     549             return self._aggregate_multiple_funcs(arg,
#     550                                                   _level=_level,
# --> 551                                                   _axis=_axis), None
#     552         else:
#     553             result = None
#
# ~/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/base.py in _aggregate_multiple_funcs(self, arg, _level, _axis)
#     595                     colg = self._gotitem(col, ndim=1,
#     596                                          subset=obj.iloc[:, index])
# --> 597                     results.append(colg.aggregate(arg))
#     598                     keys.append(col)
#     599                 except (TypeError, DataError):
#
# ~/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3483             # but not the class list / tuple itself.
#    3484             ret = self._aggregate_multiple_funcs(func_or_funcs,
# -> 3485                                                  (_level or 0) + 1)
#    3486         else:
#    3487             cyfunc = self._is_cython_func(func_or_funcs)
#
# ~/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _aggregate_multiple_funcs(self, arg, _level)
#    3556                 obj._reset_cache()
#    3557                 obj._selection = name
# -> 3558             results[name] = obj.aggregate(func)
#    3559
#    3560         if any(isinstance(x, DataFrame) for x in compat.itervalues(results)):
#
# ~/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3477         _level = kwargs.pop('_level', None)
#    3478         if isinstance(func_or_funcs, compat.string_types):
# -> 3479             return getattr(self, func_or_funcs)(*args, **kwargs)
#    3480
#    3481         if isinstance(func_or_funcs, collections.Iterable):
#
# ~/anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in nunique(self, dropna)
#    3747
#    3748         try:
# -> 3749             sorter = np.lexsort((val, ids))
#    3750         except TypeError:  # catches object dtypes
#    3751             assert val.dtype == object, \
#
# KeyboardInterrupt:

# %%
#将user_basic_info.csv 和 user_behavior_info.csv中的字符值编码成可以训练的数值类型，合并
class2id = {}
id2class = {}
def mergeBasicTables(baseTable):
    resTable = baseTable.merge(user_basic_info, how='left', on='uid', suffixes=('_base0', '_ubaf'))
    resTable = resTable.merge(user_behavior_info, how='left', on='uid', suffixes=('_base1', '_ubef'))
    cat_columns = ['city','prodName','color','carrier','os','ct']
    for c in cat_columns:
        resTable[c] = resTable[c].apply(lambda x: x if type(x)==str else str(x))
        sort_temp = sorted(list(set(resTable[c])))  
        class2id[c+'2id'] = dict(zip(sort_temp, range(1, len(sort_temp)+1)))
        id2class['id2'+c] = dict(zip(range(1,len(sort_temp)+1), sort_temp))
        resTable[c] = resTable[c].apply(lambda x: class2id[c+'2id'][x])
        
    return resTable

# %%
#处理app使用相关数据
#对user_app_actived.csv简单统计
#将之前训练的appuseProcess.csv进行合并
def mergeAppData(baseTable):
    resTable = baseTable.merge(user_app_actived, how='left', on='uid')
    resTable['appId'] = resTable['appId'].apply(lambda x: len(list(x.split('#'))))
    appusedTable = pd.read_csv("appuseProcessed.csv")
    resTable = resTable.merge(appusedTable, how='left', on='uid')
    resTable[['category', 'usage_most_used_category']] = resTable[['category', 'usage_most_used_category']].fillna(41)
    resTable = resTable.fillna(0)
    #print(resTable[:5])
    return resTable

# %%
#合并用户基本特征以及app使用相关特征，作为训练集和测试集
df_train = mergeAppData(mergeBasicTables(age_train))
df_test = mergeAppData(mergeBasicTables(age_test))
print(df_train.shape)
print(df_test.shape)
# Out:
# (2010000, 34)
# (502500, 33)

# %%
#训练模型

from sklearn.feature_selection import SelectFromModel, VarianceThreshold, SelectKBest, chi2, mutual_info_classif, f_classif
from sklearn.preprocessing import Imputer
from sklearn.ensemble import ExtraTreesClassifier

import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score
from sklearn.model_selection import StratifiedKFold

# %%
print("训练模型：")
param = {
        'boosting': 'dart',
        'learning_rate': 0.02,
        'lambda_l1': 0.05,
        'lambda_l2': 0.1,
        'max_depth': 20,
        'objective': 'multiclass',
        'num_class': 7,
        'num_leaves': 16383,
        'min_data_in_leaf': 31,
        'max_bin': 255,
        'feature_fraction': 0.95,
        'metric': 'multi_error',
        'device':'gpu',
        'num_threads': 8,
        'drop_rate': 0.05
        }

X = df_train.drop(['age_group','uid'], axis=1)
y = df_train['age_group']
uid = df_test['uid']
test = df_test.drop('uid', axis=1)

xx_score = []
cv_pred = []
skf = StratifiedKFold(n_splits=5, random_state=2019, shuffle=True)
for index, (train_index, vali_index) in enumerate(skf.split(X, y)):
    print(index)
    x_train, y_train, x_vali, y_vali = np.array(X)[train_index], np.array(y)[train_index], np.array(X)[vali_index], np.array(y)[vali_index]
    train = lgb.Dataset(x_train, y_train)
    vali =lgb.Dataset(x_vali, y_vali)
    print("training start...")
    model = lgb.train(param, train, num_boost_round=10000, valid_sets=[vali], early_stopping_rounds=100)
    xx_pred = model.predict(x_vali,num_iteration=model.best_iteration)
    xx_pred = [np.argmax(x) for x in xx_pred]
    xx_score.append(f1_score(y_vali,xx_pred,average='weighted'))
    y_test = model.predict(test,num_iteration=model.best_iteration)
    y_test = [np.argmax(x) for x in y_test]
    if index == 0:
        cv_pred = np.array(y_test).reshape(-1, 1)
    else:
        cv_pred = np.hstack((cv_pred, np.array(y_test).reshape(-1, 1)))
        
submit = []
for line in cv_pred:
    submit.append(np.argmax(np.bincount(line)))
df = pd.DataFrame({'id':uid.as_matrix(),'label':submit})
df.to_csv('submission.csv',index=False)
# Out:
# 训练模型：
# 0
# training start...
# [1]	valid_0's multi_error: 0.701493
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\callback.py:189: UserWarning: Early stopping is not available in dart mode
#   warnings.warn('Early stopping is not available in dart mode')
# [512]	valid_0's multi_error: 0.569214
# [513]	valid_0's multi_error: 0.569184
# [514]	valid_0's multi_error: 0.569114
# [515]	valid_0's multi_error: 0.569204
# [516]	valid_0's multi_error: 0.569244
# [517]	valid_0's multi_error: 0.569246
# [518]	valid_0's multi_error: 0.569206
# [519]	valid_0's multi_error: 0.569095
# [520]	valid_0's multi_error: 0.569017
# [521]	valid_0's multi_error: 0.569047
# [522]	valid_0's multi_error: 0.569085
# [523]	valid_0's multi_error: 0.56904
# [524]	valid_0's multi_error: 0.569216
# [525]	valid_0's multi_error: 0.569246
# [526]	valid_0's multi_error: 0.569351
# [527]	valid_0's multi_error: 0.569313
# [528]	valid_0's multi_error: 0.569301
# [529]	valid_0's multi_error: 0.569311
# [530]	valid_0's multi_error: 0.569348
# [531]	valid_0's multi_error: 0.569226
# [532]	valid_0's multi_error: 0.569187
# [533]	valid_0's multi_error: 0.569017
# [534]	valid_0's multi_error: 0.569037
# [535]	valid_0's multi_error: 0.569027
# [536]	valid_0's multi_error: 0.569005
# [537]	valid_0's multi_error: 0.568993
# [538]	valid_0's multi_error: 0.568998
# [539]	valid_0's multi_error: 0.568965
# [540]	valid_0's multi_error: 0.569
# [541]	valid_0's multi_error: 0.56897
# [542]	valid_0's multi_error: 0.568973
# [543]	valid_0's multi_error: 0.569025
# [544]	valid_0's multi_error: 0.568948
# [545]	valid_0's multi_error: 0.568993
# [546]	valid_0's multi_error: 0.569035
# [547]	valid_0's multi_error: 0.56907
# [548]	valid_0's multi_error: 0.569062
# [549]	valid_0's multi_error: 0.569229
# [550]	valid_0's multi_error: 0.569104
# [551]	valid_0's multi_error: 0.56907
# [552]	valid_0's multi_error: 0.569087
# [553]	valid_0's multi_error: 0.569017
# [554]	valid_0's multi_error: 0.569047
# [555]	valid_0's multi_error: 0.569067
# [556]	valid_0's multi_error: 0.569077
# [557]	valid_0's multi_error: 0.56908
# [558]	valid_0's multi_error: 0.569007
# [559]	valid_0's multi_error: 0.568883
# [560]	valid_0's multi_error: 0.568975
# [561]	valid_0's multi_error: 0.56899
# [562]	valid_0's multi_error: 0.56905
# [563]	valid_0's multi_error: 0.568963
# [564]	valid_0's multi_error: 0.568893
# [565]	valid_0's multi_error: 0.568955
# [566]	valid_0's multi_error: 0.568953
# [567]	valid_0's multi_error: 0.568943
# [568]	valid_0's multi_error: 0.56894
# [569]	valid_0's multi_error: 0.5689
# [570]	valid_0's multi_error: 0.568836
# [571]	valid_0's multi_error: 0.568886

# %%
y_test = model.predict(test)
    y_test = [np.argmax(x) for x in y_test]
    if index == 0:
        cv_pred = np.array(y_test).reshape(-1, 1)
    else:
        cv_pred = np.hstack((cv_pred, np.array(y_test).reshape(-1, 1)))
submit = []
for line in cv_pred:
    submit.append(np.argmax(np.bincount(line)))
df = pd.DataFrame({'id':uid.as_matrix(),'label':submit})
df.to_csv('submission.csv',index=False)

# %%
age_train['age_group'].nunique()
# Out:
# 6

# %%
history
# Out:
# history
